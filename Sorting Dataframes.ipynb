# %%
import pandas as pd
import numpy as np

#read the dataset
data_BM=pd.read_csv ("C:/Users/DELL/Pandas Part 1/bigmart_data.csv")

# drop the null values
data_BM=data_BM.dropna(how="any")

#view the top results
data_BM.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
#sort by year
sorted_data=data_BM.sort_values(by='Outlet_Establishment_Year')

#print sorted data
sorted_data[:10]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4244           NCQ43       17.750               LF         0.111209
# 3331           FDH40       11.600          Regular         0.078864
# 6795           FDL56       14.100          Low Fat         0.125676
# 3328           FDL13       13.850          Regular         0.056272
# 3326           FDX58       13.150          Low Fat         0.043727
# 3316           FDO44       12.600          Low Fat         0.087380
# 3339           DRD13       15.000          Low Fat         0.049039
# 3313           FDS56        5.785          Regular         0.038725
# 3307           DRI01        7.970          Low Fat         0.034424
# 3305           FDE47       14.150          low fat         0.037877
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4244                 Others  107.7912            OUT013
# 3331           Frozen Foods   83.2276            OUT013
# ...

# %%
data_BM [['Item_Identifier','Outlet_Establishment_Year', 'Item_Outlet_Sales']]
# Out:
#      Item_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales
# 0              FDA15                       1999          3735.1380
# 1              DRC01                       2009           443.4228
# 2              FDN15                       1999          2097.2700
# 4              NCD19                       1987           994.7052
# 5              FDP36                       2009           556.6088
# ...              ...                        ...                ...
# 8517           FDF53                       1997          3608.6360
# 8518           FDF22                       1987          2778.3834
# 8520           NCJ29                       2004          1193.1136
# 8521           FDN46                       2009          1845.5976
# 8522           DRG01                       1997           765.6700
#
# [4650 rows x 3 columns]

# %%
#sort in place and descending order

data_BM.sort_values(by='Outlet_Establishment_Year', ascending=False, inplace=True)
data_BM[:2]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2825           FDL16        12.85          Low Fat         0.169139
# 7389           NCD42        16.50          Low Fat         0.012689
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 2825        Frozen Foods   46.4060            OUT018
# 7389  Health and Hygiene   39.7506            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2825                       2009      Medium               Tier 3
# 7389                       2009      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 2825  Supermarket Type2           186.4240
# 7389  Supermarket Type2           227.7036

# %%
#read the dataset
data_BM=pd.read_csv("C:/Users/DELL/Pandas Part 1/bigmart_data.csv")
#drop the null values
data_BM=data_BM.dropna(how="any")

#sort by multiple columns
sorted_data=data_BM.sort_values(by=['Outlet_Establishment_Year', 'Item_Outlet_Sales'])
sorted_data [:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2370           NCA06       20.500          Low Fat         0.143164
# 4174           FDI60        7.220          Regular         0.038289
# 2244           FDZ27        7.935               LF         0.017142
# 3684           FDV38       19.250          Low Fat         0.101689
# 1209           FDU21       11.800              reg         0.076657
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2370     Household   34.9190            OUT013                       1987
# 4174  Baking Goods   64.7510            OUT013                       1987
# 2244         Dairy   50.0350            OUT013                       1987
# 3684         Dairy   54.6956            OUT013                       1987
# 1209   Snack Foods   32.3558            OUT013                       1987
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
#changed the order of columns
data_BM.sort_values(by=['Item_Outlet_Sales', 'Outlet_Establishment_Year'])
data_BM [:5]
data_BM.iloc[:20]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# 13           FDS46       17.600          Regular         0.047257
# 14           FDF32       16.350          Low Fat         0.068024
# 15           FDP49        9.000          Regular         0.069089
# 16           NCB42       11.800          Low Fat         0.008596
# ...

# %%
# sort_index
data_BM.sort_index(inplace=True)
data_BM[:20]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# 13           FDS46       17.600          Regular         0.047257
# 14           FDF32       16.350          Low Fat         0.068024
# 15           FDP49        9.000          Regular         0.069089
# 16           NCB42       11.800          Low Fat         0.008596
# ...
